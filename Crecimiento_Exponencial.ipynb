# %% [markdown]
# <a href="https://colab.research.google.com/github/rtrochepy/machine_learning/blob/main/Crecimiento_Exponencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Parámetros iniciales
n = 10  # Longitud promedio actual en bytes
m = 20  # Longitud promedio estimada con nombres más largos en bytes
P_0 = 1000  # Cantidad actual de registros
a = 1.05  # Tasa de crecimiento (5%)
t = np.arange(0, 10)  # Tiempo: 10 períodos (puede ser días, meses, años, etc.)

# %%
# Cálculos
S_t_n = n * P_0 * np.power(a, t)
S_t_m = m * P_0 * np.power(a, t)

# %%
# Visualización
plt.figure(figsize=(10,6))
plt.plot(t, S_t_n, label=f'Longitud promedio = {n} bytes')
plt.plot(t, S_t_m, label=f'Longitud promedio = {m} bytes', linestyle='--')
plt.title('Impacto en Almacenamiento con Crecimiento Exponencial')
plt.xlabel('Tiempo (t)')
plt.ylabel('Almacenamiento Total (bytes)')
plt.legend()
plt.grid(True)
plt.show()
